# %% [markdown]
# <h1>Final Project Introduction</h1>
# <h2>The Battle of Restaurants in Munich</h2>

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Business Problem and Audience](#business)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# <h3>Introduction</h3><a name="introduction"></a>
#
# The topic of lifelong learning is an important one. Since it was partly no longer possible to pursue my original hobbies during my time at Corona, I used the time to familiarize myself with the topic of machine learning. I have always been interested in data and I am convinced that it is becoming more and more important for making business decisions. To that end, I've done various online courses, watched instructional videos, and done exercises. To get even more involved in the topic, I signed up for the "IBM Data Science Certificate".In this course I got familiar with Python programming in general, various libraries (numpy, pandas...) but also with the IBM Cloud itself.
#
# The "Capstone Project" now encompasses what was previously learned over the past weeks and months. To accomplish the last task, I created a Jupyter notebook, with the associated code.
# For the further analysis I chose Munich, because from my point of view it is suitable for such an analysis and it is not far away from where I live.

# %% [markdown]
# <h3>Business Problem and Audience</h3><a name="business"></a>
#
# Munich is a well-known city. Millions of visitors come there every year. Probably one of the most popular events is the Oktoberfest in Munich. This is visited by about 6 million people from all over the world. As a tourist, I know the problem when you are looking for a restaurant in a foreign city and first faces the challenge of which part of town to go to at all. Of course, it should not be just any restaurant, but correspond to his own preferences.
#
# With this exercise I would like to examine the different districts of Munich and divide them into different categories. Where do you find a high density of German food, where do you find a lot of Mediterranean food or if it has to go fast, also fast food.
#
# The audience of this exercise are tourists from near and far.

# %% [markdown]
# <h3>Data</h3><a name="data"></a>
#
# The following data was used for this project.
#
# - Wikipedia Data - Munich Neighborhoods https://de.wikipedia.org/wiki/Stadtbezirke_M%C3%BCnchens
# - Geographical Data (Longitude and Latitude)
# - Foursquare Data

# %% [markdown]
# <h4>Wikipedia Data - Munich Neighborhoods</h4>

# %% [markdown]
# The Munich Neigborhoods data was extracted by Wikipedia with beautiful soup
# This data includes the following:
# - Nr.
# - Neighbourhood
# - Area
# - Inhabitants
# - Density (Inhabitants/km²)
# - Foreigners
#
# For this project only the Neighbourhood names where used the rest of the data was droped.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url_path = ('https://de.wikipedia.org/wiki/Stadtbezirke_M%C3%BCnchens')
html_text = requests.get(url_path).text
soup = BeautifulSoup(html_text)
wiki_tables = soup.find_all('table', {'class': 'wikitable sortable'})
first_table = wiki_tables[0].find_all("tr")
# Extracting the text from the table cells
table_list = []

for tr in first_table:
    td = tr.find_all('td')
    row = [ele.text.strip() for ele in td]
    table_list.append(row)
    
df = pd.DataFrame(table_list, columns=['Nr.', 'Stadtbezirk', 'Fläche(km²)', 'Einwohner', 'Dichte(Einw./km²)', 'Ausländer(%)'])
df = df.dropna(how='all').reset_index(drop=True)
df = df.drop(['Fläche(km²)', 'Einwohner', 'Dichte(Einw./km²)', 'Ausländer(%)'], axis = 1)
df.head()
# Out:
#   Nr.                   Stadtbezirk
# 0   1                Altstadt-Lehel
# 1   2  Ludwigsvorstadt-Isarvorstadt
# 2   3                   Maxvorstadt
# 3   4                Schwabing-West
# 4   5                 Au-Haidhausen

# %% [markdown]
# The above dataframe shows the data extracted from Wikipedia. These were further enriched with longitude and latitude data and combined with the Foursquare data.

# %%
df.shape
# Out:
# (26, 2)

# %% [markdown]
# This resulted in a dataframe with the 25 districts of Munich. The last row is Munich itself. Thats why there are 26 entries.

# %% [markdown]
# <h4>Geographical Data</h4>
#
# To add longitude (latitude and longitude) to the data from each district, I used geopy.et

# %%
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim
   
# declare an empty list to store
# latitude and longitude of values 
# of city column
longitude = []
latitude = []
   
# function to find the coordinate
# of a given city 
def findGeocode(city):
       
    # try and catch is used to overcome
    # the exception thrown by geolocator
    # using geocodertimedout  
    try:
          
        # Specify the user_agent as your
        # app name it should not be none
        geolocator = Nominatim(user_agent="MunichGeoData")
          
        return geolocator.geocode(city)
      
    except GeocoderTimedOut:
          
        return findGeocode(city)    
  
# each value from city column
# will be fetched and sent to
# function find_geocode   
for i in (df["Stadtbezirk"]):
      
    if findGeocode(i) != None:
           
        loc = findGeocode(i)
          
        # coordinates returned from 
        # function is stored into
        # two separate list
        latitude.append(loc.latitude)
        longitude.append(loc.longitude)
       
    # if coordinate for a city not
    # found, insert "NaN" indicating 
    # missing value 
    else:
        latitude.append(np.nan)
        longitude.append(np.nan)

# %%
# now add this column to dataframe
df["Longitude"] = longitude
df["Latitude"] = latitude
  
df
# Out:
#    Nr.                                        Stadtbezirk  Longitude  \
# 0    1                                     Altstadt-Lehel  11.574582
# 1    2                       Ludwigsvorstadt-Isarvorstadt  11.573366
# 2    3                                        Maxvorstadt  11.562418
# 3    4                                     Schwabing-West  11.569873
# 4    5                                      Au-Haidhausen  11.598334
# 5    6                                           Sendling  11.539083
# 6    7                                  Sendling-Westpark  11.519333
# 7    8                                   Schwanthalerhöhe  11.541057
# 8    9                              Neuhausen-Nymphenburg  11.531517
# 9   10                                            Moosach  11.875678
# 10  11                              Milbertshofen-Am Hart  11.575043
# 11  12                                 Schwabing-Freimann  11.608583
# 12  13                                        Bogenhausen  11.633484
# 13  14                                       Berg am Laim  11.633451
# 14  15                                     Trudering-Riem  11.674057
# 15  16                                 Ramersdorf-Perlach  11.633371
# 16  17                            Obergiesing-Fasangarten  11.590683
# 17  18                            Untergiesing-Harlaching  11.570189
# 18  19  Thalkirchen-Obersendling-Forstenried-Fürstenri...  11.508051
# 19  20                                             Hadern  11.481842
# 20  21                                 Pasing-Obermenzing  11.468434
# 21  22                         Aubing-Lochhausen-Langwied  11.400221
# 22  23                                Allach-Untermenzing  11.462973
# 23  24                             Feldmoching-Hasenbergl  11.520409
# 24  25                                               Laim  11.177422
# 25                               Landeshauptstadt München  11.596432
#
#      Latitude
# 0   48.137828
# 1   48.130340
# 2   48.151092
# 3   48.168271
# 4   48.130274
# 5   48.118012
# 6   48.118031
# 7   48.133782
# 8   48.154222
# 9   48.031726
# 10  48.182385
# 11  48.189278
# 12  48.154782
# 13  48.123483
# 14  48.138838
# 15  48.100894
# 16  48.103934
# 17  48.114963
# 18  48.084213
# 19  48.118064
# 20  48.152363
# 21  48.165059
# 22  48.195157
# 23  48.218462
# 24  45.865249
# 25  48.183699

# %%
df_munich = df[df['Stadtbezirk'] == 'Landeshauptstadt München']
type(df_munich)

longitude = df_munich['Longitude'].values[0]
latitude =  df_munich['Latitude'].values[0]

df_munich.head()
# Out:
#    Nr.               Stadtbezirk  Longitude   Latitude
# 25      Landeshauptstadt München  11.596432  48.183699

# %%
print('The Longitude and Latitude of Munich is', longitude, 'and', latitude)
# Out:
# The Longitude and Latitude of Munich is 11.5964316 and 48.1836994

# %% [markdown]
# The Longiutde and Latitude of Moosach was not recognized correctly so I corrected them manually.

# %%
df.loc[df.Stadtbezirk == 'Moosach', 'Longitude'] = 11.5057
df.loc[df.Stadtbezirk == 'Moosach', 'Latitude'] = 48.1799

# %%
import folium # map rendering library
# create map of Manhattan using latitude and longitude values
map_munich = folium.Map(location=[latitude, longitude], zoom_start=11)
# add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Stadtbezirk']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_munich)  
    
map_munich
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_fec2577815494f9f887c0e9320933023%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fec2577815494f9f887c0e9320933023%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fec2577815494f9f887c0e9320933023%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_fec2577815494f9f887c0e9320933023%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B48.1836994%2C11.5964316%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <h4>Foursquare Data</h4>

# %% [markdown]
# Additionally, Foursquare data was used to identify different venues from Munich and to assign them to the districts of Munich.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
neighborhood_latitude = df_munich.loc[25, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df_munich.loc[25, 'Longitude'] # neighborhood longitude value

neighborhood_name = df_munich.loc[25, 'Stadtbezirk'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Landeshauptstadt München are 48.1836994, 11.5964316.

# %%
# type your answer here
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=MHYEVMQYGJXUSZGVHDT2E1SEDSH0T13POGSBTHMCH5YWCTBW&client_secret=K0CAO03DCHBAWZGS0P4WJRTWVDIDGSAQH4HFLIB5M4CGUMHM&v=20180605&ll=48.1836994,11.5964316&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6123f87b735e082b36366799'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Alte Heide - Hirschau',
#   'headerFullLocation': 'Alte Heide - Hirschau, Munich',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 19,
#   'suggestedBounds': {'ne': {'lat': 48.188199404500004,
#     'lng': 11.603168216906269},
#    'sw': {'lat': 48.1791993955, 'lng': 11.589694983093732}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b6e112498eef48c838b15f',
#        'name': "Grillin' me softly",
#        'location': {'address': 'Täglich wechselnder Standort',
#         'crossStreet': 'Do: Max-Diamand-Str. 7',
#         'lat': 48.182678687078166,
#         'lng': 11.595554015467604,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.182678687078166,
#           'lng': 11.595554015467604}],
#         'distance': 130,
#         'postalCode': '80937',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Täglich wechselnder Standort (Do: Max-Diamand-Str. 7)',
#          '80937 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53b6e112498eef48c838b15f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb73fee1344b7138f7c9e04',
#        'name': 'Dolzer Masskonfektionäre',
#        'location': {'address': 'Willhelm-Wagenfeld-Str. 18',
#         'lat': 48.18340659622562,
#         'lng': 11.592057623194325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18340659622562,
#           'lng': 11.592057623194325}],
#         'distance': 326,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Willhelm-Wagenfeld-Str. 18',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb73fee1344b7138f7c9e04-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548ed023498ed29d2bc632ba',
#        'name': 'Leonardi',
#        'location': {'address': 'Marcel-Breuer-Str. 8',
#         'lat': 48.18156765304559,
#         'lng': 11.596856896366436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18156765304559,
#           'lng': 11.596856896366436}],
#         'distance': 239,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Marcel-Breuer-Str. 8',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548ed023498ed29d2bc632ba-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '599a8bc1780eee45bcddb567',
#        'name': 'Bite Delite',
#        'location': {'address': 'Domagstr. 34',
#         'lat': 48.18205135536673,
#         'lng': 11.597205704638785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18205135536673,
#           'lng': 11.597205704638785}],
#         'distance': 192,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagstr. 34', '80807 München', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-599a8bc1780eee45bcddb567-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57909d24498eb132ea5c8efe',
#        'name': 'hasia - Asian Food & Drink',
#        'location': {'address': 'Alfred-Arndt-Straße 1',
#         'lat': 48.18262082486448,
#         'lng': 11.594411946298132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18262082486448,
#           'lng': 11.594411946298132}],
#         'distance': 192,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Straße 1',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57909d24498eb132ea5c8efe-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d77611c9b476a31cb0125f9',
#        'name': 'Suite Novotel Parkstadt Schwabing',
#        'location': {'address': 'Lyonel Feininger Strasse 22',
#         'lat': 48.179845764601026,
#         'lng': 11.593549976871941,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.179845764601026,
#           'lng': 11.593549976871941}],
#         'distance': 479,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'neighborhood': 'Alte Heide - Hirschau',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Lyonel Feininger Strasse 22',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d77611c9b476a31cb0125f9-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c65816ec2ead13a0a21b180',
#        'name': 'dm-drogerie markt',
#        'location': {'address': 'Alfred-Arndt-Straße 1',
#         'crossStreet': 'Parkstadt-Center',
#         'lat': 48.1828079,
#         'lng': 11.5941084,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.1828079,
#           'lng': 11.5941084}],
#         'distance': 198,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Straße 1 (Parkstadt-Center)',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '5745c2e4498e11e7bccabdbd',
#          'name': 'Drugstore',
#          'pluralName': 'Drugstores',
#          'shortName': 'Drugstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '449282360'}},
#       'referralId': 'e-0-4c65816ec2ead13a0a21b180-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c31b8b8213c2d7f3851345d',
#        'name': 'REWE',
#        'location': {'address': 'Alfred-Arndt-Str. 1',
#         'lat': 48.1829748,
#         'lng': 11.5937559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.1829748,
#           'lng': 11.5937559}],
#         'distance': 214,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Str. 1',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '559609765'}},
#       'referralId': 'e-0-4c31b8b8213c2d7f3851345d-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be2a20cb02ec9b650454dc0',
#        'name': 'Coffee Fellows',
#        'location': {'address': 'Domagkstr. 26',
#         'lat': 48.18339876453055,
#         'lng': 11.594658970292729,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18339876453055,
#           'lng': 11.594658970292729}],
#         'distance': 135,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagkstr. 26', '80807 München', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be2a20cb02ec9b650454dc0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b51afb3f964a520935227e3',
#        'name': 'Parkstadt-Center',
#        'location': {'address': 'Alfred-Arndt-Str. 1',
#         'lat': 48.18257630485794,
#         'lng': 11.59471686786489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18257630485794,
#           'lng': 11.59471686786489}],
#         'distance': 178,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Str. 1',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b51afb3f964a520935227e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c31b6763896e21e8861e790',
#        'name': 'mammaminuti',
#        'location': {'address': 'Domagkstr. 26',
#         'lat': 48.183397151096344,
#         'lng': 11.594629150468498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.183397151096344,
#           'lng': 11.594629150468498}],
#         'distance': 137,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagkstr. 26', '80807 München', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c31b6763896e21e8861e790-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0435362632ec142bffb485',
#        'name': 'Gasthaus Domagk',
#        'location': {'address': 'Fritz-Winter-Str.',
#         'lat': 48.18359,
#         'lng': 11.598015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18359,
#           'lng': 11.598015}],
#         'distance': 118,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'neighborhood': 'Alte Heide - Hirschau',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Fritz-Winter-Str.',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a0435362632ec142bffb485-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ef1adf1d5fb1f1f36cf1f41',
#        'name': 'H Domagkstraße',
#        'location': {'address': 'Domagkstr.',
#         'lat': 48.18492969910566,
#         'lng': 11.59493573843299,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18492969910566,
#           'lng': 11.59493573843299}],
#         'distance': 176,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagkstr.', '80807 München', 'Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ef1adf1d5fb1f1f36cf1f41-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c454a3974ffc9285ec776cc',
#        'name': 'Bienen-Apotheke Parkstadt Schwabing',
#        'location': {'address': 'Alfred-Arndt-Str. 1',
#         'lat': 48.18272177472506,
#         'lng': 11.59415707921653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18272177472506,
#           'lng': 11.59415707921653}],
#         'distance': 200,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'neighborhood': 'Schwabing - Freimann, Munich',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Str. 1',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94845298'}},
#       'referralId': 'e-0-4c454a3974ffc9285ec776cc-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55786e26498ed0d325c388de',
#        'name': 'Vitello',
#        'location': {'address': 'Domagkstr. 26',
#         'lat': 48.18317308015887,
#         'lng': 11.594045844443736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18317308015887,
#           'lng': 11.594045844443736}],
#         'distance': 186,
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagkstr. 26', 'München', 'Deutschland']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55786e26498ed0d325c388de-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4543e3f97fbe9ad35ebc30',
#        'name': 'Privat Bäckerei Wimmer',
#        'location': {'address': 'Wilhelm-Wagenfeld-Str. 6',
#         'lat': 48.182693,
#         'lng': 11.593864,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.182693,
#           'lng': 11.593864}],
#         'distance': 221,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'neighborhood': 'Alte Heide - Hirschau',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Wilhelm-Wagenfeld-Str. 6',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4543e3f97fbe9ad35ebc30-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c46f9adc047be9a61042f79',
#        'name': 'PENNY',
#        'location': {'address': 'Alfred-Arndt-Straße 1',
#         'lat': 48.1827321,
#         'lng': 11.5935918,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.1827321,
#           'lng': 11.5935918}],
#         'distance': 236,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alfred-Arndt-Straße 1',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '476193334'}},
#       'referralId': 'e-0-4c46f9adc047be9a61042f79-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d087202143cb60cda6b7ba6',
#        'name': 'H Zaunweg',
#        'location': {'address': 'Domagkstr. 52',
#         'crossStreet': 'Zaunweg',
#         'lat': 48.180753290251154,
#         'lng': 11.601116361800772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.180753290251154,
#           'lng': 11.601116361800772}],
#         'distance': 477,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Domagkstr. 52 (Zaunweg)',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d087202143cb60cda6b7ba6-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ceab62d60d11b002c24d013',
#        'name': "L'Osteria München Bauhausplatz",
#        'location': {'address': 'Bauhausplatz 4-6',
#         'lat': 48.18695728824648,
#         'lng': 11.592092377298172,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.18695728824648,
#           'lng': 11.592092377298172}],
#         'distance': 485,
#         'postalCode': '80807',
#         'cc': 'DE',
#         'city': 'München',
#         'state': 'Bayern',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bauhausplatz 4-6',
#          '80807 München',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ceab62d60d11b002c24d013-18'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import json # library to handle JSON files

from pandas.io.json import json_normalize

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /tmp/ipykernel_191/2023952869.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                          name        categories        lat        lng
# 0          Grillin' me softly        Food Truck  48.182679  11.595554
# 1    Dolzer Masskonfektionäre    Clothing Store  48.183407  11.592058
# 2                    Leonardi         Cafeteria  48.181568  11.596857
# 3                 Bite Delite              Café  48.182051  11.597206
# 4  hasia - Asian Food & Drink  Asian Restaurant  48.182621  11.594412

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 19 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Stadtbezirk', 
                  'Stadtbezirk Latitude', 
                  'Stadtbezirk Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
munich_venues = getNearbyVenues(
                                    names=df['Stadtbezirk'],
                                    latitudes=df['Latitude'],
                                    longitudes=df['Longitude']
                                  )
# Out:
# Altstadt-Lehel
# Ludwigsvorstadt-Isarvorstadt
# Maxvorstadt
# Schwabing-West
# Au-Haidhausen
# Sendling
# Sendling-Westpark
# Schwanthalerhöhe
# Neuhausen-Nymphenburg
# Moosach
# Milbertshofen-Am Hart
# Schwabing-Freimann
# Bogenhausen
# Berg am Laim
# Trudering-Riem
# Ramersdorf-Perlach
# Obergiesing-Fasangarten
# Untergiesing-Harlaching
# Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln
# Hadern
# Pasing-Obermenzing
# Aubing-Lochhausen-Langwied
# Allach-Untermenzing
# Feldmoching-Hasenbergl
# Laim
# Landeshauptstadt München

# %%
print(munich_venues.shape)
munich_venues.head()

munich_venues = munich_venues[munich_venues['Venue Category'].str.contains('Restaurant')]
# Out:
# (669, 7)

# %%
munich_venues.groupby('Stadtbezirk').count()
# Out:
#                               Stadtbezirk Latitude  Stadtbezirk Longitude  \
# Stadtbezirk
# Allach-Untermenzing                              1                      1
# Altstadt-Lehel                                  23                     23
# Au-Haidhausen                                   43                     43
# Bogenhausen                                      3                      3
# Feldmoching-Hasenbergl                           1                      1
# Hadern                                           2                      2
# Landeshauptstadt München                         5                      5
# Ludwigsvorstadt-Isarvorstadt                    28                     28
# Maxvorstadt                                     13                     13
# Milbertshofen-Am Hart                            4                      4
# Moosach                                          4                      4
# Neuhausen-Nymphenburg                           19                     19
# Obergiesing-Fasangarten                          1                      1
# Pasing-Obermenzing                               2                      2
# Ramersdorf-Perlach                               4                      4
# Schwabing-Freimann                               4                      4
# Schwabing-West                                   8                      8
# Schwanthalerhöhe                                16                     16
# Sendling                                        11                     11
# Sendling-Westpark                                2                      2
# Untergiesing-Harlaching                          8                      8
#
#                               Venue  Venue Latitude  Venue Longitude  \
# Stadtbezirk
# Allach-Untermenzing               1               1                1
# Altstadt-Lehel                   23              23               23
# Au-Haidhausen                    43              43               43
# Bogenhausen                       3               3                3
# Feldmoching-Hasenbergl            1               1                1
# Hadern                            2               2                2
# Landeshauptstadt München          5               5                5
# Ludwigsvorstadt-Isarvorstadt     28              28               28
# Maxvorstadt                      13              13               13
# Milbertshofen-Am Hart             4               4                4
# Moosach                           4               4                4
# Neuhausen-Nymphenburg            19              19               19
# Obergiesing-Fasangarten           1               1                1
# Pasing-Obermenzing                2               2                2
# Ramersdorf-Perlach                4               4                4
# Schwabing-Freimann                4               4                4
# Schwabing-West                    8               8                8
# Schwanthalerhöhe                 16              16               16
# Sendling                         11              11               11
# Sendling-Westpark                 2               2                2
# Untergiesing-Harlaching           8               8                8
#
#                               Venue Category
# Stadtbezirk
# Allach-Untermenzing                        1
# Altstadt-Lehel                            23
# Au-Haidhausen                             43
# Bogenhausen                                3
# Feldmoching-Hasenbergl                     1
# Hadern                                     2
# Landeshauptstadt München                   5
# Ludwigsvorstadt-Isarvorstadt              28
# Maxvorstadt                               13
# Milbertshofen-Am Hart                      4
# Moosach                                    4
# Neuhausen-Nymphenburg                     19
# Obergiesing-Fasangarten                    1
# Pasing-Obermenzing                         2
# Ramersdorf-Perlach                         4
# Schwabing-Freimann                         4
# Schwabing-West                             8
# Schwanthalerhöhe                          16
# Sendling                                  11
# Sendling-Westpark                          2
# Untergiesing-Harlaching                    8

# %%
print('There are {} uniques categories.'.format(len(munich_venues['Venue Category'].unique())))
# Out:
# There are 35 uniques categories.

# %%
print (nearby_venues['categories'].value_counts()[0:10])
# Out:
# Supermarket           2
# Italian Restaurant    2
# Bus Stop              2
# Food Truck            1
# Clothing Store        1
# Cafeteria             1
# Café                  1
# Asian Restaurant      1
# Hotel                 1
# Drugstore             1
# Name: categories, dtype: int64

# %%
nearby_venues
# Out:
#                                    name                  categories  \
# 0                    Grillin' me softly                  Food Truck
# 1              Dolzer Masskonfektionäre              Clothing Store
# 2                              Leonardi                   Cafeteria
# 3                           Bite Delite                        Café
# 4            hasia - Asian Food & Drink            Asian Restaurant
# 5     Suite Novotel Parkstadt Schwabing                       Hotel
# 6                     dm-drogerie markt                   Drugstore
# 7                                  REWE                 Supermarket
# 8                        Coffee Fellows                 Coffee Shop
# 9                      Parkstadt-Center               Shopping Mall
# 10                          mammaminuti          Italian Restaurant
# 11                      Gasthaus Domagk                  Restaurant
# 12                       H Domagkstraße                    Bus Stop
# 13  Bienen-Apotheke Parkstadt Schwabing                    Pharmacy
# 14                              Vitello  Modern European Restaurant
# 15               Privat Bäckerei Wimmer                      Bakery
# 16                                PENNY                 Supermarket
# 17                            H Zaunweg                    Bus Stop
# 18       L'Osteria München Bauhausplatz          Italian Restaurant
#
#           lat        lng
# 0   48.182679  11.595554
# 1   48.183407  11.592058
# 2   48.181568  11.596857
# 3   48.182051  11.597206
# 4   48.182621  11.594412
# 5   48.179846  11.593550
# 6   48.182808  11.594108
# 7   48.182975  11.593756
# 8   48.183399  11.594659
# 9   48.182576  11.594717
# 10  48.183397  11.594629
# 11  48.183590  11.598015
# 12  48.184930  11.594936
# 13  48.182722  11.594157
# 14  48.183173  11.594046
# 15  48.182693  11.593864
# 16  48.182732  11.593592
# 17  48.180753  11.601116
# 18  48.186957  11.592092

# %%
munich_venues
# Out:
#                   Stadtbezirk  Stadtbezirk Latitude  Stadtbezirk Longitude  \
# 2              Altstadt-Lehel             48.137828              11.574582
# 13             Altstadt-Lehel             48.137828              11.574582
# 20             Altstadt-Lehel             48.137828              11.574582
# 24             Altstadt-Lehel             48.137828              11.574582
# 38             Altstadt-Lehel             48.137828              11.574582
# ..                        ...                   ...                    ...
# 654  Landeshauptstadt München             48.183699              11.596432
# 660  Landeshauptstadt München             48.183699              11.596432
# 661  Landeshauptstadt München             48.183699              11.596432
# 664  Landeshauptstadt München             48.183699              11.596432
# 668  Landeshauptstadt München             48.183699              11.596432
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 2                Augustiner Klosterwirt       48.138649        11.572527
# 13                     Andechser am Dom       48.138302        11.573778
# 20                  Restaurant Dallmayr       48.138489        11.576791
# 24   Nürnberger Bratwurst Glöckl am Dom       48.138191        11.574165
# 38                         Leger am Dom       48.138262        11.572932
# ..                                  ...             ...              ...
# 654          hasia - Asian Food & Drink       48.182621        11.594412
# 660                         mammaminuti       48.183397        11.594629
# 661                     Gasthaus Domagk       48.183590        11.598015
# 664                             Vitello       48.183173        11.594046
# 668      L'Osteria München Bauhausplatz       48.186957        11.592092
#
#                  Venue Category
# 2             German Restaurant
# 13          Bavarian Restaurant
# 20            German Restaurant
# 24          Bavarian Restaurant
# 38                   Restaurant
# ..                          ...
# 654            Asian Restaurant
# 660          Italian Restaurant
# 661                  Restaurant
# 664  Modern European Restaurant
# 668          Italian Restaurant
#
# [202 rows x 7 columns]

# %% [markdown]
# Now we have a dataframe munich_venues that contains all Foursquare data and the corresponding city district. Thus, the data collection and preparation phase is completed and we can proceed with the analysis.

# %% [markdown]
# <h3>Methodology</h3><a name="methodology"></a>

# %% [markdown]
# In the analysis, we will focus on analyzing and categorizing the prepared data, and then on dividing the individual neighborhoods into categories.
#
# First, we use a OneHot encoding to confer the different restaurant types into columns.
#
# In the next step, we use k-means clustering to divide the data into different categories. The result is presented in a map and in a table form.

# %% [markdown]
# <h3>Analysis</h3><a name="analysis"></a>

# %%
# one hot encoding
munich_onehot = pd.get_dummies(munich_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
munich_onehot['Stadtbezirk'] = munich_venues['Stadtbezirk'] 

# move neighborhood column to the first column
fixed_columns = [munich_onehot.columns[-1]] + list(munich_onehot.columns[:-1])
munich_onehot = munich_onehot[fixed_columns]

munich_onehot.head()
# Out:
#        Stadtbezirk  Afghan Restaurant  American Restaurant  Asian Restaurant  \
# 2   Altstadt-Lehel                  0                    0                 0
# 13  Altstadt-Lehel                  0                    0                 0
# 20  Altstadt-Lehel                  0                    0                 0
# 24  Altstadt-Lehel                  0                    0                 0
# 38  Altstadt-Lehel                  0                    0                 0
#
#     Austrian Restaurant  Bavarian Restaurant  Chinese Restaurant  \
# 2                     0                    0                   0
# 13                    0                    1                   0
# 20                    0                    0                   0
# 24                    0                    1                   0
# 38                    0                    0                   0
#
#     Dim Sum Restaurant  Doner Restaurant  Dumpling Restaurant  ...  \
# 2                    0                 0                    0  ...
# 13                   0                 0                    0  ...
# 20                   0                 0                    0  ...
# 24                   0                 0                    0  ...
# 38                   0                 0                    0  ...
#
#     Ramen Restaurant  Restaurant  Seafood Restaurant  Spanish Restaurant  \
# 2                  0           0                   0                   0
# 13                 0           0                   0                   0
# 20                 0           0                   0                   0
# 24                 0           0                   0                   0
# 38                 0           1                   0                   0
#
#     Sushi Restaurant  Tapas Restaurant  Thai Restaurant  Turkish Restaurant  \
# 2                  0                 0                0                   0
# 13                 0                 0                0                   0
# 20                 0                 0                0                   0
# 24                 0                 0                0                   0
# 38                 0                 0                0                   0
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 2                               0                      0
# 13                              0                      0
# 20                              0                      0
# 24                              0                      0
# 38                              0                      0
#
# [5 rows x 36 columns]

# %%
munich_onehot.shape
# Out:
# (202, 36)

# %%
munich_grouped = munich_onehot.groupby('Stadtbezirk').mean().reset_index()
munich_grouped
# Out:
#                      Stadtbezirk  Afghan Restaurant  American Restaurant  \
# 0            Allach-Untermenzing           0.000000             0.000000
# 1                 Altstadt-Lehel           0.000000             0.000000
# 2                  Au-Haidhausen           0.000000             0.000000
# 3                    Bogenhausen           0.000000             0.000000
# 4         Feldmoching-Hasenbergl           0.000000             0.000000
# 5                         Hadern           0.000000             0.000000
# 6       Landeshauptstadt München           0.000000             0.000000
# 7   Ludwigsvorstadt-Isarvorstadt           0.071429             0.035714
# 8                    Maxvorstadt           0.000000             0.000000
# 9          Milbertshofen-Am Hart           0.000000             0.000000
# 10                       Moosach           0.000000             0.250000
# 11         Neuhausen-Nymphenburg           0.000000             0.000000
# 12       Obergiesing-Fasangarten           0.000000             0.000000
# 13            Pasing-Obermenzing           0.000000             0.000000
# 14            Ramersdorf-Perlach           0.000000             0.000000
# 15            Schwabing-Freimann           0.000000             0.000000
# 16                Schwabing-West           0.000000             0.000000
# 17              Schwanthalerhöhe           0.000000             0.000000
# 18                      Sendling           0.000000             0.000000
# 19             Sendling-Westpark           0.000000             0.000000
# 20       Untergiesing-Harlaching           0.000000             0.000000
#
#     Asian Restaurant  Austrian Restaurant  Bavarian Restaurant  \
# 0           0.000000             0.000000             0.000000
# 1           0.000000             0.000000             0.304348
# 2           0.000000             0.000000             0.046512
# 3           0.000000             0.000000             0.000000
# 4           0.000000             0.000000             0.000000
# 5           0.000000             0.000000             0.000000
# 6           0.200000             0.000000             0.000000
# 7           0.107143             0.000000             0.071429
# 8           0.076923             0.000000             0.000000
# 9           0.000000             0.000000             0.000000
# 10          0.000000             0.000000             0.000000
# 11          0.000000             0.052632             0.052632
# 12          0.000000             0.000000             0.000000
# 13          0.000000             0.000000             0.000000
# 14          0.000000             0.000000             0.000000
# 15          0.000000             0.000000             0.000000
# 16          0.000000             0.125000             0.000000
# 17          0.125000             0.000000             0.000000
# 18          0.000000             0.090909             0.000000
# 19          0.000000             0.000000             0.000000
# 20          0.000000             0.000000             0.000000
#
#     Chinese Restaurant  Dim Sum Restaurant  Doner Restaurant  \
# 0             0.000000            0.000000          0.000000
# 1             0.000000            0.000000          0.000000
# 2             0.023256            0.000000          0.023256
# 3             0.000000            0.000000          0.000000
# 4             0.000000            0.000000          0.000000
# 5             0.000000            0.000000          0.000000
# 6             0.000000            0.000000          0.000000
# 7             0.000000            0.035714          0.000000
# 8             0.000000            0.076923          0.000000
# 9             0.000000            0.000000          0.000000
# 10            0.000000            0.000000          0.000000
# 11            0.000000            0.000000          0.052632
# 12            0.000000            0.000000          0.000000
# 13            0.000000            0.000000          0.000000
# 14            0.000000            0.000000          0.000000
# 15            0.000000            0.000000          0.000000
# 16            0.125000            0.000000          0.000000
# 17            0.062500            0.000000          0.062500
# 18            0.000000            0.000000          0.090909
# 19            0.000000            0.000000          0.000000
# 20            0.000000            0.000000          0.000000
#
#     Dumpling Restaurant  ...  Ramen Restaurant  Restaurant  \
# 0              0.000000  ...          0.000000    0.000000
# 1              0.043478  ...          0.000000    0.217391
# 2              0.000000  ...          0.000000    0.023256
# 3              0.000000  ...          0.000000    0.000000
# 4              0.000000  ...          0.000000    0.000000
# 5              0.000000  ...          0.000000    0.000000
# 6              0.000000  ...          0.000000    0.200000
# 7              0.000000  ...          0.000000    0.071429
# 8              0.000000  ...          0.076923    0.076923
# 9              0.000000  ...          0.000000    0.000000
# 10             0.000000  ...          0.000000    0.000000
# 11             0.000000  ...          0.052632    0.052632
# 12             0.000000  ...          0.000000    0.000000
# 13             0.000000  ...          0.000000    0.500000
# 14             0.000000  ...          0.000000    0.000000
# 15             0.000000  ...          0.000000    0.000000
# 16             0.000000  ...          0.000000    0.000000
# 17             0.000000  ...          0.000000    0.000000
# 18             0.000000  ...          0.000000    0.090909
# 19             0.000000  ...          0.000000    0.000000
# 20             0.000000  ...          0.000000    0.125000
#
#     Seafood Restaurant  Spanish Restaurant  Sushi Restaurant  \
# 0             0.000000            0.000000          0.000000
# 1             0.043478            0.000000          0.000000
# 2             0.023256            0.046512          0.023256
# 3             0.000000            0.000000          0.000000
# 4             0.000000            0.000000          0.000000
# 5             0.000000            0.000000          0.500000
# 6             0.000000            0.000000          0.000000
# 7             0.000000            0.000000          0.035714
# 8             0.000000            0.000000          0.076923
# 9             0.000000            0.000000          0.000000
# 10            0.000000            0.000000          0.000000
# 11            0.000000            0.052632          0.105263
# 12            0.000000            0.000000          0.000000
# 13            0.000000            0.000000          0.000000
# 14            0.000000            0.000000          0.000000
# 15            0.000000            0.000000          0.000000
# 16            0.000000            0.000000          0.000000
# 17            0.000000            0.000000          0.125000
# 18            0.000000            0.090909          0.000000
# 19            0.000000            0.000000          0.000000
# 20            0.000000            0.000000          0.000000
#
#     Tapas Restaurant  Thai Restaurant  Turkish Restaurant  \
# 0           0.000000         0.000000            0.000000
# 1           0.000000         0.000000            0.000000
# 2           0.023256         0.046512            0.046512
# 3           0.000000         0.000000            0.000000
# 4           0.000000         0.000000            0.000000
# 5           0.000000         0.000000            0.000000
# 6           0.000000         0.000000            0.000000
# 7           0.035714         0.000000            0.000000
# 8           0.000000         0.000000            0.000000
# 9           0.000000         0.250000            0.000000
# 10          0.000000         0.000000            0.000000
# 11          0.000000         0.000000            0.052632
# 12          0.000000         0.000000            0.000000
# 13          0.000000         0.000000            0.000000
# 14          0.000000         0.000000            0.000000
# 15          0.000000         0.000000            0.000000
# 16          0.000000         0.125000            0.000000
# 17          0.000000         0.062500            0.000000
# 18          0.000000         0.000000            0.090909
# 19          0.000000         0.000000            0.000000
# 20          0.000000         0.000000            0.000000
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0                        0.000000               0.000000
# 1                        0.043478               0.000000
# 2                        0.046512               0.000000
# 3                        0.000000               0.000000
# 4                        0.000000               0.000000
# 5                        0.000000               0.000000
# 6                        0.000000               0.000000
# 7                        0.071429               0.107143
# 8                        0.000000               0.153846
# 9                        0.000000               0.000000
# 10                       0.000000               0.000000
# 11                       0.000000               0.105263
# 12                       0.000000               0.000000
# 13                       0.000000               0.000000
# 14                       0.000000               0.000000
# 15                       0.000000               0.000000
# 16                       0.000000               0.250000
# 17                       0.062500               0.062500
# 18                       0.000000               0.181818
# 19                       0.000000               0.000000
# 20                       0.000000               0.125000
#
# [21 rows x 36 columns]

# %%
num_top_venues = 5

for hood in munich_grouped['Stadtbezirk']:
    print("----"+hood+"----")
    temp = munich_grouped[munich_grouped['Stadtbezirk'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Allach-Untermenzing----
#                  venue  freq
# 0   Italian Restaurant   1.0
# 1           Restaurant   0.0
# 2  Japanese Restaurant   0.0
# 3    Jewish Restaurant   0.0
# 4     Kebab Restaurant   0.0
#
#
# ----Altstadt-Lehel----
#                            venue  freq
# 0            Bavarian Restaurant  0.30
# 1                     Restaurant  0.22
# 2              German Restaurant  0.17
# 3             Italian Restaurant  0.13
# 4  Vegetarian / Vegan Restaurant  0.04
#
#
# ----Au-Haidhausen----
#                  venue  freq
# 0   Italian Restaurant  0.21
# 1    German Restaurant  0.14
# 2    Indian Restaurant  0.12
# 3    French Restaurant  0.07
# 4  Bavarian Restaurant  0.05
#
#
# ----Bogenhausen----
#                  venue  freq
# 0   Italian Restaurant  0.67
# 1     Greek Restaurant  0.33
# 2   Israeli Restaurant  0.00
# 3  Japanese Restaurant  0.00
# 4    Jewish Restaurant  0.00
#
#
# ----Feldmoching-Hasenbergl----
#                  venue  freq
# 0     Greek Restaurant   1.0
# 1    Afghan Restaurant   0.0
# 2   Israeli Restaurant   0.0
# 3  Japanese Restaurant   0.0
# 4    Jewish Restaurant   0.0
#
#
# ----Hadern----
#                  venue  freq
# 0     Sushi Restaurant   0.5
# 1    German Restaurant   0.5
# 2    Afghan Restaurant   0.0
# 3     Ramen Restaurant   0.0
# 4  Japanese Restaurant   0.0
#
#
# ----Landeshauptstadt München----
#                         venue  freq
# 0          Italian Restaurant   0.4
# 1                  Restaurant   0.2
# 2            Asian Restaurant   0.2
# 3  Modern European Restaurant   0.2
# 4         Japanese Restaurant   0.0
#
#
# ----Ludwigsvorstadt-Isarvorstadt----
#                            venue  freq
# 0             Italian Restaurant  0.14
# 1          Vietnamese Restaurant  0.11
# 2               Asian Restaurant  0.11
# 3              French Restaurant  0.07
# 4  Vegetarian / Vegan Restaurant  0.07
#
#
# ----Maxvorstadt----
#                    venue  freq
# 0  Vietnamese Restaurant  0.15
# 1      German Restaurant  0.15
# 2     Falafel Restaurant  0.08
# 3       Sushi Restaurant  0.08
# 4             Restaurant  0.08
#
#
# ----Milbertshofen-Am Hart----
#                venue  freq
# 0   Greek Restaurant  0.50
# 1    Thai Restaurant  0.25
# 2  German Restaurant  0.25
# 3  Afghan Restaurant  0.00
# 4   Ramen Restaurant  0.00
#
#
# ----Moosach----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1   American Restaurant  0.25
# 2     German Restaurant  0.25
# 3    Italian Restaurant  0.25
# 4     Afghan Restaurant  0.00
#
#
# ----Neuhausen-Nymphenburg----
#                    venue  freq
# 0      Indian Restaurant  0.11
# 1     Italian Restaurant  0.11
# 2       Sushi Restaurant  0.11
# 3  Vietnamese Restaurant  0.11
# 4    Bavarian Restaurant  0.05
#
#
# ----Obergiesing-Fasangarten----
#                  venue  freq
# 0    German Restaurant   1.0
# 1    Afghan Restaurant   0.0
# 2   Israeli Restaurant   0.0
# 3  Japanese Restaurant   0.0
# 4    Jewish Restaurant   0.0
#
#
# ----Pasing-Obermenzing----
#                  venue  freq
# 0   Italian Restaurant   0.5
# 1           Restaurant   0.5
# 2  Japanese Restaurant   0.0
# 3    Jewish Restaurant   0.0
# 4     Kebab Restaurant   0.0
#
#
# ----Ramersdorf-Perlach----
#                  venue  freq
# 0    German Restaurant  0.75
# 1   Italian Restaurant  0.25
# 2   Israeli Restaurant  0.00
# 3  Japanese Restaurant  0.00
# 4    Jewish Restaurant  0.00
#
#
# ----Schwabing-Freimann----
#                   venue  freq
# 0  Fast Food Restaurant  0.75
# 1      Greek Restaurant  0.25
# 2     Afghan Restaurant  0.00
# 3    Italian Restaurant  0.00
# 4     Jewish Restaurant  0.00
#
#
# ----Schwabing-West----
#                    venue  freq
# 0  Vietnamese Restaurant  0.25
# 1     Italian Restaurant  0.25
# 2     Chinese Restaurant  0.12
# 3        Thai Restaurant  0.12
# 4    Japanese Restaurant  0.12
#
#
# ----Schwanthalerhöhe----
#                 venue  freq
# 0  Italian Restaurant  0.19
# 1    Asian Restaurant  0.12
# 2   German Restaurant  0.12
# 3    Sushi Restaurant  0.12
# 4    Doner Restaurant  0.06
#
#
# ----Sendling----
#                    venue  freq
# 0      German Restaurant  0.27
# 1  Vietnamese Restaurant  0.18
# 2       Doner Restaurant  0.09
# 3     Turkish Restaurant  0.09
# 4     Spanish Restaurant  0.09
#
#
# ----Sendling-Westpark----
#                   venue  freq
# 0    Italian Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2    Israeli Restaurant   0.0
# 3   Japanese Restaurant   0.0
# 4     Jewish Restaurant   0.0
#
#
# ----Untergiesing-Harlaching----
#                    venue  freq
# 0      German Restaurant  0.38
# 1  Vietnamese Restaurant  0.12
# 2     Italian Restaurant  0.12
# 3       Kebab Restaurant  0.12
# 4       Greek Restaurant  0.12

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Stadtbezirk']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Stadtbezirk_venues_sorted = pd.DataFrame(columns=columns)
Stadtbezirk_venues_sorted['Stadtbezirk'] = munich_grouped['Stadtbezirk']

for ind in np.arange(munich_grouped.shape[0]):
    Stadtbezirk_venues_sorted.iloc[ind, 1:] = return_most_common_venues(munich_grouped.iloc[ind, :], num_top_venues)

Stadtbezirk_venues_sorted.head()
# Out:
#               Stadtbezirk 1st Most Common Venue 2nd Most Common Venue  \
# 0     Allach-Untermenzing    Italian Restaurant            Restaurant
# 1          Altstadt-Lehel   Bavarian Restaurant            Restaurant
# 2           Au-Haidhausen    Italian Restaurant     German Restaurant
# 3             Bogenhausen    Italian Restaurant      Greek Restaurant
# 4  Feldmoching-Hasenbergl      Greek Restaurant     Afghan Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue          5th Most Common Venue  \
# 0   Japanese Restaurant     Jewish Restaurant               Kebab Restaurant
# 1     German Restaurant    Italian Restaurant  Vegetarian / Vegan Restaurant
# 2     Indian Restaurant     French Restaurant            Bavarian Restaurant
# 3    Israeli Restaurant   Japanese Restaurant              Jewish Restaurant
# 4    Israeli Restaurant   Japanese Restaurant              Jewish Restaurant
#
#        6th Most Common Venue          7th Most Common Venue  \
# 0  Middle Eastern Restaurant     Modern European Restaurant
# 1        Dumpling Restaurant             Falafel Restaurant
# 2            Thai Restaurant  Vegetarian / Vegan Restaurant
# 3           Kebab Restaurant      Middle Eastern Restaurant
# 4           Kebab Restaurant      Middle Eastern Restaurant
#
#         8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Ramen Restaurant     Afghan Restaurant     Israeli Restaurant
# 1          Seafood Restaurant     Jewish Restaurant       Kebab Restaurant
# 2          Spanish Restaurant    Turkish Restaurant     Seafood Restaurant
# 3  Modern European Restaurant      Ramen Restaurant      Afghan Restaurant
# 4  Modern European Restaurant      Ramen Restaurant             Restaurant

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
# set number of clusters
kclusters = 5

munich_grouped_clustering = munich_grouped.drop('Stadtbezirk', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(munich_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# /tmp/ipykernel_191/4142880739.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   munich_grouped_clustering = munich_grouped.drop('Stadtbezirk', 1)
# array([3, 0, 0, 3, 4, 0, 0, 0, 0, 4], dtype=int32)

# %%
df.head()
# Out:
#   Nr.                   Stadtbezirk  Longitude   Latitude
# 0   1                Altstadt-Lehel  11.574582  48.137828
# 1   2  Ludwigsvorstadt-Isarvorstadt  11.573366  48.130340
# 2   3                   Maxvorstadt  11.562418  48.151092
# 3   4                Schwabing-West  11.569873  48.168271
# 4   5                 Au-Haidhausen  11.598334  48.130274

# %%
# add clustering labels
Stadtbezirk_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

munich_merged = df

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
munich_merged = munich_merged.join(Stadtbezirk_venues_sorted.set_index('Stadtbezirk'), on='Stadtbezirk')

munich_merged.head() # check the last columns!
# Out:
#   Nr.                   Stadtbezirk  Longitude   Latitude  Cluster Labels  \
# 0   1                Altstadt-Lehel  11.574582  48.137828             0.0
# 1   2  Ludwigsvorstadt-Isarvorstadt  11.573366  48.130340             0.0
# 2   3                   Maxvorstadt  11.562418  48.151092             0.0
# 3   4                Schwabing-West  11.569873  48.168271             0.0
# 4   5                 Au-Haidhausen  11.598334  48.130274             0.0
#
#    1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0    Bavarian Restaurant             Restaurant     German Restaurant
# 1     Italian Restaurant  Vietnamese Restaurant      Asian Restaurant
# 2  Vietnamese Restaurant      German Restaurant    Falafel Restaurant
# 3  Vietnamese Restaurant     Italian Restaurant    Chinese Restaurant
# 4     Italian Restaurant      German Restaurant     Indian Restaurant
#
#   4th Most Common Venue          5th Most Common Venue 6th Most Common Venue  \
# 0    Italian Restaurant  Vegetarian / Vegan Restaurant   Dumpling Restaurant
# 1     French Restaurant  Vegetarian / Vegan Restaurant            Restaurant
# 2      Sushi Restaurant                     Restaurant      Ramen Restaurant
# 3       Thai Restaurant            Japanese Restaurant   Austrian Restaurant
# 4     French Restaurant            Bavarian Restaurant       Thai Restaurant
#
#            7th Most Common Venue    8th Most Common Venue  \
# 0             Falafel Restaurant       Seafood Restaurant
# 1              Afghan Restaurant      Bavarian Restaurant
# 2             Israeli Restaurant  Grilled Meat Restaurant
# 3             Turkish Restaurant         Tapas Restaurant
# 4  Vegetarian / Vegan Restaurant       Spanish Restaurant
#
#   9th Most Common Venue         10th Most Common Venue
# 0     Jewish Restaurant               Kebab Restaurant
# 1     Indian Restaurant           Fast Food Restaurant
# 2     Indian Restaurant             Dim Sum Restaurant
# 3      Sushi Restaurant  Vegetarian / Vegan Restaurant
# 4    Turkish Restaurant             Seafood Restaurant

# %%
munich_merged['Cluster Labels'].isnull().values.any()
munich_merged['Cluster Labels'].isnull().sum()
munich_merged.shape
# Out:
# (26, 15)

# %%
munich_merged = munich_merged.dropna()

# converting 'Cluster Labels' from float to int
munich_merged['Cluster Labels'] = munich_merged['Cluster Labels'].astype(int)

# %%
munich_merged.head()
# Out:
#   Nr.                   Stadtbezirk  Longitude   Latitude  Cluster Labels  \
# 0   1                Altstadt-Lehel  11.574582  48.137828               0
# 1   2  Ludwigsvorstadt-Isarvorstadt  11.573366  48.130340               0
# 2   3                   Maxvorstadt  11.562418  48.151092               0
# 3   4                Schwabing-West  11.569873  48.168271               0
# 4   5                 Au-Haidhausen  11.598334  48.130274               0
#
#    1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0    Bavarian Restaurant             Restaurant     German Restaurant
# 1     Italian Restaurant  Vietnamese Restaurant      Asian Restaurant
# 2  Vietnamese Restaurant      German Restaurant    Falafel Restaurant
# 3  Vietnamese Restaurant     Italian Restaurant    Chinese Restaurant
# 4     Italian Restaurant      German Restaurant     Indian Restaurant
#
#   4th Most Common Venue          5th Most Common Venue 6th Most Common Venue  \
# 0    Italian Restaurant  Vegetarian / Vegan Restaurant   Dumpling Restaurant
# 1     French Restaurant  Vegetarian / Vegan Restaurant            Restaurant
# 2      Sushi Restaurant                     Restaurant      Ramen Restaurant
# 3       Thai Restaurant            Japanese Restaurant   Austrian Restaurant
# 4     French Restaurant            Bavarian Restaurant       Thai Restaurant
#
#            7th Most Common Venue    8th Most Common Venue  \
# 0             Falafel Restaurant       Seafood Restaurant
# 1              Afghan Restaurant      Bavarian Restaurant
# 2             Israeli Restaurant  Grilled Meat Restaurant
# 3             Turkish Restaurant         Tapas Restaurant
# 4  Vegetarian / Vegan Restaurant       Spanish Restaurant
#
#   9th Most Common Venue         10th Most Common Venue
# 0     Jewish Restaurant               Kebab Restaurant
# 1     Indian Restaurant           Fast Food Restaurant
# 2     Indian Restaurant             Dim Sum Restaurant
# 3      Sushi Restaurant  Vegetarian / Vegan Restaurant
# 4    Turkish Restaurant             Seafood Restaurant

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(munich_merged['Latitude'], munich_merged['Longitude'], munich_merged['Stadtbezirk'], munich_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_2637e54470f94002bc5646e4c7ee66d2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2637e54470f94002bc5646e4c7ee66d2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2637e54470f94002bc5646e4c7ee66d2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_2637e54470f94002bc5646e4c7ee66d2%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B48.1836994%2C11.5964316%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# **Cluster 1 - The Allround Food Cluster**

# %%
munich_merged.loc[munich_merged['Cluster Labels'] == 0, munich_merged.columns[[1] + list(range(5, munich_merged.shape[1]))]]
# Out:
#                      Stadtbezirk  1st Most Common Venue  \
# 0                 Altstadt-Lehel    Bavarian Restaurant
# 1   Ludwigsvorstadt-Isarvorstadt     Italian Restaurant
# 2                    Maxvorstadt  Vietnamese Restaurant
# 3                 Schwabing-West  Vietnamese Restaurant
# 4                  Au-Haidhausen     Italian Restaurant
# 5                       Sendling      German Restaurant
# 7               Schwanthalerhöhe     Italian Restaurant
# 8          Neuhausen-Nymphenburg      Indian Restaurant
# 9                        Moosach   Fast Food Restaurant
# 17       Untergiesing-Harlaching      German Restaurant
# 19                        Hadern       Sushi Restaurant
# 25      Landeshauptstadt München     Italian Restaurant
#
#     2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0              Restaurant     German Restaurant          Italian Restaurant
# 1   Vietnamese Restaurant      Asian Restaurant           French Restaurant
# 2       German Restaurant    Falafel Restaurant            Sushi Restaurant
# 3      Italian Restaurant    Chinese Restaurant             Thai Restaurant
# 4       German Restaurant     Indian Restaurant           French Restaurant
# 5   Vietnamese Restaurant      Doner Restaurant          Turkish Restaurant
# 7        Asian Restaurant     German Restaurant            Sushi Restaurant
# 8      Italian Restaurant      Sushi Restaurant       Vietnamese Restaurant
# 9     American Restaurant     German Restaurant          Italian Restaurant
# 17  Vietnamese Restaurant    Italian Restaurant            Kebab Restaurant
# 19      German Restaurant     Afghan Restaurant            Ramen Restaurant
# 25             Restaurant      Asian Restaurant  Modern European Restaurant
#
#             5th Most Common Venue      6th Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant        Dumpling Restaurant
# 1   Vegetarian / Vegan Restaurant                 Restaurant
# 2                      Restaurant           Ramen Restaurant
# 3             Japanese Restaurant        Austrian Restaurant
# 4             Bavarian Restaurant            Thai Restaurant
# 5              Spanish Restaurant                 Restaurant
# 7                Doner Restaurant  Middle Eastern Restaurant
# 8             Bavarian Restaurant           Greek Restaurant
# 9               Afghan Restaurant          Jewish Restaurant
# 17               Greek Restaurant                 Restaurant
# 19            Japanese Restaurant          Jewish Restaurant
# 25            Japanese Restaurant          Jewish Restaurant
#
#             7th Most Common Venue      8th Most Common Venue  \
# 0              Falafel Restaurant         Seafood Restaurant
# 1               Afghan Restaurant        Bavarian Restaurant
# 2              Israeli Restaurant    Grilled Meat Restaurant
# 3              Turkish Restaurant           Tapas Restaurant
# 4   Vegetarian / Vegan Restaurant         Spanish Restaurant
# 5               Indian Restaurant        Austrian Restaurant
# 7               French Restaurant      Vietnamese Restaurant
# 8              Turkish Restaurant         Spanish Restaurant
# 9                Kebab Restaurant  Middle Eastern Restaurant
# 17               Sushi Restaurant         Spanish Restaurant
# 19               Kebab Restaurant  Middle Eastern Restaurant
# 25               Kebab Restaurant  Middle Eastern Restaurant
#
#          9th Most Common Venue         10th Most Common Venue
# 0            Jewish Restaurant               Kebab Restaurant
# 1            Indian Restaurant           Fast Food Restaurant
# 2            Indian Restaurant             Dim Sum Restaurant
# 3             Sushi Restaurant  Vegetarian / Vegan Restaurant
# 4           Turkish Restaurant             Seafood Restaurant
# 5           Dim Sum Restaurant            Dumpling Restaurant
# 7              Thai Restaurant             Chinese Restaurant
# 8                   Restaurant               Ramen Restaurant
# 9   Modern European Restaurant               Ramen Restaurant
# 17          Seafood Restaurant               Tapas Restaurant
# 19  Modern European Restaurant                     Restaurant
# 25            Ramen Restaurant              Afghan Restaurant

# %% [markdown]
# **Cluster 2 - The Mediterran Food Cluster with Fast Food alternatives**

# %%
munich_merged.loc[munich_merged['Cluster Labels'] == 1, munich_merged.columns[[1] + list(range(5, munich_merged.shape[1]))]]
# Out:
#            Stadtbezirk 1st Most Common Venue 2nd Most Common Venue  \
# 6    Sendling-Westpark    Italian Restaurant  Fast Food Restaurant
# 11  Schwabing-Freimann  Fast Food Restaurant      Greek Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6     Israeli Restaurant   Japanese Restaurant     Jewish Restaurant
# 11     Afghan Restaurant    Italian Restaurant     Jewish Restaurant
#
#    6th Most Common Venue      7th Most Common Venue  \
# 6       Kebab Restaurant  Middle Eastern Restaurant
# 11      Kebab Restaurant  Middle Eastern Restaurant
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 6   Modern European Restaurant      Ramen Restaurant      Afghan Restaurant
# 11  Modern European Restaurant      Ramen Restaurant             Restaurant

# %% [markdown]
# **Cluster 3 - The German Focused Food Cluster with foreign alternatives**

# %%
munich_merged.loc[munich_merged['Cluster Labels'] == 2, munich_merged.columns[[1] + list(range(5, munich_merged.shape[1]))]]
# Out:
#                 Stadtbezirk 1st Most Common Venue 2nd Most Common Venue  \
# 15       Ramersdorf-Perlach     German Restaurant    Italian Restaurant
# 16  Obergiesing-Fasangarten     German Restaurant     Afghan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 15    Israeli Restaurant   Japanese Restaurant     Jewish Restaurant
# 16    Israeli Restaurant   Japanese Restaurant     Jewish Restaurant
#
#    6th Most Common Venue      7th Most Common Venue  \
# 15      Kebab Restaurant  Middle Eastern Restaurant
# 16      Kebab Restaurant  Middle Eastern Restaurant
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 15  Modern European Restaurant      Ramen Restaurant      Afghan Restaurant
# 16  Modern European Restaurant      Ramen Restaurant             Restaurant

# %% [markdown]
# **Cluster 4 - The Italian Dominated Exotic Food Cluster**

# %%
munich_merged.loc[munich_merged['Cluster Labels'] == 3, munich_merged.columns[[1] + list(range(5, munich_merged.shape[1]))]]
# Out:
#             Stadtbezirk 1st Most Common Venue 2nd Most Common Venue  \
# 12          Bogenhausen    Italian Restaurant      Greek Restaurant
# 20   Pasing-Obermenzing    Italian Restaurant            Restaurant
# 22  Allach-Untermenzing    Italian Restaurant            Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12    Israeli Restaurant   Japanese Restaurant     Jewish Restaurant
# 20   Japanese Restaurant     Jewish Restaurant      Kebab Restaurant
# 22   Japanese Restaurant     Jewish Restaurant      Kebab Restaurant
#
#         6th Most Common Venue       7th Most Common Venue  \
# 12           Kebab Restaurant   Middle Eastern Restaurant
# 20  Middle Eastern Restaurant  Modern European Restaurant
# 22  Middle Eastern Restaurant  Modern European Restaurant
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12  Modern European Restaurant      Ramen Restaurant      Afghan Restaurant
# 20            Ramen Restaurant     Afghan Restaurant     Israeli Restaurant
# 22            Ramen Restaurant     Afghan Restaurant     Israeli Restaurant

# %% [markdown]
# **Cluster 5 - Greek Dominated Food Cluster**

# %%
munich_merged.loc[munich_merged['Cluster Labels'] == 4, munich_merged.columns[[1] + list(range(5, munich_merged.shape[1]))]]
# Out:
#                Stadtbezirk 1st Most Common Venue 2nd Most Common Venue  \
# 10   Milbertshofen-Am Hart      Greek Restaurant       Thai Restaurant
# 23  Feldmoching-Hasenbergl      Greek Restaurant     Afghan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 10     German Restaurant     Afghan Restaurant      Ramen Restaurant
# 23    Israeli Restaurant   Japanese Restaurant     Jewish Restaurant
#
#    6th Most Common Venue      7th Most Common Venue  \
# 10     Jewish Restaurant           Kebab Restaurant
# 23      Kebab Restaurant  Middle Eastern Restaurant
#
#          8th Most Common Venue       9th Most Common Venue  \
# 10   Middle Eastern Restaurant  Modern European Restaurant
# 23  Modern European Restaurant            Ramen Restaurant
#
#    10th Most Common Venue
# 10             Restaurant
# 23             Restaurant

# %% [markdown]
# These five clusters categorize the range of restaurants in Munich

# %% [markdown]
# <h3>Results and Discussion</h3><a name="results"></a>
#
# I am always surprised about the possibilities and how data that is freely available can be used to derive new insights.
# These tools are available for free and only need to be used. I am sure that this method or tools will become much more important in the coming years. There are still so many use cases that can be implemented with this knowledge.

# %% [markdown]
# <h3>Conclusion</h3><a name="conclusion"></a>
#
# The goal was achieved to divide the individual districts into different "food clusters". Thus, tourists can choose districts that best suit their preferences. This describes a wonderful data science use case that can be implemented with free available technologies.
